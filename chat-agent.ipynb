# %%
# !pip install groq python-dotenv requests
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.3/142.3 kB 10.1 MB/s eta 0:00:00
# ...

# %%
# !pip install groq

# %%
import os

os.environ["GROQ_API_KEY"] = "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"

# %%
from groq import Groq
import os

# Initialize client
client = Groq(api_key=os.environ["GROQ_API_KEY"])

def chat_agent():
    print("🤖 AI Chat Agent (type 'exit' to stop)\n")

    messages = [
        {"role": "system", "content": "You are a helpful AI assistant."}
    ]

    while True:
        user_input = input("You: ")

        if user_input.lower() == "exit":
            print("Bot: Goodbye 👋")
            break

        messages.append({"role": "user", "content": user_input})

        response = client.chat.completions.create(
            model="mixtral-8x7b-32768",   # ✅ UPDATED MODEL
            messages=messages
        )

        reply = response.choices[0].message.content

        print("Bot:", reply)

        messages.append({"role": "assistant", "content": reply})

chat_agent()
# Out:
# 🤖 AI Chat Agent (type 'exit' to stop)
#
# You: what is python?
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# /tmp/ipykernel_19499/2846346694.py in <cell line: 0>()
#      32         messages.append({"role": "assistant", "content": reply})
#      33
# ---> 34 chat_agent()
#
# /tmp/ipykernel_19499/2846346694.py in chat_agent()
#      21         messages.append({"role": "user", "content": user_input})
#      22
# ---> 23         response = client.chat.completions.create(
#      24             model="mixtral-8x7b-32768",   # ✅ UPDATED MODEL
#      25             messages=messages
#
# ...

# %%
from groq import Groq
import os

# Check API key exists
if "GROQ_API_KEY" not in os.environ:
    raise ValueError("API Key not set properly")

client = Groq(api_key=os.environ["GROQ_API_KEY"])

def chat_agent():
    print("🤖 AI Chat Agent (type 'exit' to stop)\n")

    messages = [
        {"role": "system", "content": "You are a helpful assistant."}
    ]

    while True:
        user_input = input("You: ")

        if user_input.lower() == "exit":
            print("Bot: Goodbye 👋")
            break

        try:
            messages.append({"role": "user", "content": user_input})

            response = client.chat.completions.create(
                model="llama-3.1-8b-instant",   # ✅ WORKING MODEL
                messages=messages
            )

            reply = response.choices[0].message.content

            print("Bot:", reply)

            messages.append({"role": "assistant", "content": reply})

        except Exception as e:
            print("❌ Error:", e)

chat_agent()
# Out:
# 🤖 AI Chat Agent (type 'exit' to stop)
#
# You: ok
# Bot: It seems a bit brief. Is there anything specific you'd like help with, or would you like me to suggest some topics to explore?
